# %%
from ultralytics import YOLO

# %% [markdown]
# # Fine Tune

# %%
model = YOLO("yolo26n.pt")

# %%
result = model.train(data="/mnt/d/Computer-Vision/Tracking/football_players_detection/dataset/football_players_detection/data.yaml",
                     epochs=10,
                     imgsz=320,
                     batch=128,
                     workers=0,
                     device=0)
# Out:
# New https://pypi.org/project/ultralytics/8.4.123 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.114 🚀 Python-3.13.9 torch-2.13.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5060 Laptop GPU, 8151MiB)
# ...

# %%
best_model = YOLO('/mnt/d/Computer-Vision/Tracking/runs/detect/train-4/weights/best.pt')

# %%
metrics_val = best_model.val(data="/mnt/d/Computer-Vision/Tracking/football_players_detection/dataset/football_players_detection/data.yaml", split='test')
# Out:
# Ultralytics 8.4.114 🚀 Python-3.13.9 torch-2.13.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5060 Laptop GPU, 8151MiB)
# YOLO26n summary (fused): 122 layers, 2,375,226 parameters, 0 gradients, 5.3 GFLOPs
# WARNING ⚠️ val: Slow image access detected (ping: 1.9±0.6 ms, read: 7.3±3.3 MB/s, size: 117.7 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /mnt/d/Computer-Vision/Tracking/football_players_detection/dataset/football_players_detection/test/labels... 520 images, 23 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 520/520 116.3it/s 4.5s0.1s
# val: New cache created: /mnt/d/Computer-Vision/Tracking/football_players_detection/dataset/football_players_detection/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 33/33 8.1it/s 4.1s<0.1s
# ...

# %%
metrics_val.results_dict
# Out:
# {'metrics/precision(B)': 0.7661937519970599,
#  'metrics/recall(B)': 0.5860893701082743,
#  'metrics/mAP50(B)': 0.6147784473269412,
#  'metrics/mAP50-95(B)': 0.36187921751982455,
#  'fitness': 0.36187921751982455}

# %%
metrics_train = best_model.val(data="/mnt/d/Computer-Vision/Tracking/football_players_detection/dataset/football_players_detection/data.yaml", split='train')
# Out:
# Ultralytics 8.4.114 🚀 Python-3.13.9 torch-2.13.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5060 Laptop GPU, 8151MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 2.7±1.9 ms, read: 46.6±37.2 MB/s, size: 133.6 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /mnt/d/Computer-Vision/Tracking/football_players_detection/dataset/football_players_detection/train/labels.cache... 10308 images, 623 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10308/10308 982.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 645/645 13.7it/s 47.0s0.2ss
#                    all      10308      48810      0.809      0.609      0.661      0.399
#               football       2107       2325      0.756      0.335      0.399      0.184
#                 player       9616      46485      0.863      0.883      0.924      0.615
# ...

# %%
metrics_train.results_dict
# Out:
# {'metrics/precision(B)': 0.8092187615052672,
#  'metrics/recall(B)': 0.6087991162748189,
#  'metrics/mAP50(B)': 0.6611720143777693,
#  'metrics/mAP50-95(B)': 0.39942590898411046,
#  'fitness': 0.39942590898411046}

# %% [markdown]
# # Tracking

# %%
results = best_model.track(source="/mnt/d/Computer-Vision/Tracking/football_players_detection/video/video2.mp4",
                           save=True,
                           show=True,
                           tracker="bytetrack.yaml")
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
# QObject::moveToThread: Current thread (0xa275f020) is not the object's thread (0xa283ce60).
# Cannot move to target thread (0xa275f020)
#
# QObject::moveToThread: Current thread (0xa275f020) is not the object's thread (0xa283ce60).
# Cannot move to target thread (0xa275f020)
#
# QObject::moveToThread: Current thread (0xa275f020) is not the object's thread (0xa283ce60).
# Cannot move to target thread (0xa275f020)
#
# ...
